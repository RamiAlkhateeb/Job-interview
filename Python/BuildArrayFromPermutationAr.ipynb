# %% [markdown]
# 1. السؤالالمشكلة: بناء مصفوفة من تبديلة صفرية (Permutation)بفرض لديك مصفوفة nums تبدأ من الصفر، قم ببناء مصفوفة ans بنفس الطول بحيث يكون ans[i] = nums[nums[i]] لكل عنصر، ثم قم بإرجاعها.ملاحظة: التبديلة الصفرية هي مصفوفة تحتوي على أرقام فريدة تبدأ من $0$ إلى $n-1$.

# %%
def build_array(nums):
    # This creates a new list where each element at index i 
    # is the value found at nums[nums[i]]
    return [nums[nums[i]] for i in range(len(nums))]

# Example usage:
nums = [0, 2, 1, 5, 3, 4]
print(build_array(nums))  # Output: [0, 1, 2, 4, 5, 3]
# Out:
# [0, 1, 2, 4, 5, 3]

# %% [markdown]
# 3. الشرح التقنيالفكرة تعتمد على الفهرسة المتداخلة. بدلاً من أخذ القيمة الموجودة في الموقع $i$ مباشرة، نستخدم تلك القيمة كـ "مؤشر" للبحث عن قيمة أخرى داخل نفس المصفوفة.التعقيد الزمني (Time Complexity): $O(n)$ لأننا نمر على كل عنصر مرة واحدة فقط.تعقيد المساحة (Space Complexity): $O(n)$ لأننا أنشأنا مصفوفة جديدة لتخزين النتائج.
#
# 4. التشبيه: لعبة صيد الكنز 🗺️تخيل إنك عم تلعب لعبة فيها 5 صناديق، وكل صندوق بقلبه رقم.رحت عـ الصندوق رقم 0، لقيت جواته ورقة مكتوب عليها: "شوف الصندوق رقم 2".رحت عـ الصندوق رقم 2 ولقيت الجائزة الحقيقية.سجلت الجائزة اللي لقيتها بالصندوق 2 كأول نتيجة بـ "دفترك" (المصفوفة الجديدة).أنت ببساطة عم تتبع تعليمات "القفزة المزدوجة" لتوصل للقيمة النهائية.
#
# 5. مثال من الواقع: دليل المكاتب 🏢تخيل إنك عم تدور على مدير بشركة كبيرة:بتشوف قائمة الاستقبال (Index $i$).القائمة ما بتعطيك اسم المدير فوراً، بتعطيك رقم المكتب (nums[i]).بتروح على رقم المكتب هاد وبتشوف اللوحة اللي عالباب (nums[nums[i]]).الاسم اللي عاللوحة هو النتيجة النهائية اللي بدك ياها.
