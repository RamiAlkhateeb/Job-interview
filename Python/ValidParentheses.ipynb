# %% [markdown]
# ## **الجزء الثاني: النسخة العربية**
#
# ### **1. السؤال**
#
# **المشكلة: الأقواس الصالحة (Valid Parentheses)**
# بفرض لديك نص `s` يحتوي فقط على الرموز التالية: `'('` و `')'` و `'{'` و `'}'` و `'['` و `']'`. المطلوب هو تحديد ما إذا كان النص "صالحاً" أم لا.
#
# يكون النص صالحاً إذا:
#
# 1. تم إغلاق كل قوس مفتوح بنفس نوع القوس.
# 2. تم إغلاق الأقواس بالترتيب الصحيح.
# 3. كل قوس إغلاق له قوس فتح مطابق يسبقه.
#
# **أمثلة:**
#
# * **المثال 1:** المدخل `"()"`. النتيجة: `true`.
# * **المثال 2:** المدخل `"()[]{}"`. النتيجة: `true`.
# * **المثال 3:** المدخل `"(]"`. النتيجة: `false`.
# * **المثال 4:** المدخل `"([])"`. النتيجة: `true`.
#
# ---
#
# ### **2. التحليل التقني: كيف وصلنا للحل؟ (التفكير بصوت عالٍ)**
#
# عندما أواجه مشكلة تتعلق بالبنى "المتداخلة" أو "ترتيب الإغلاق"، يتبادر إلى ذهني فوراً مفهوم **LIFO (ما يدخل آخراً يخرج أولاً)**.
#
# #### **أولاً: فشل منطق "العد" (Counting)**
#
# أول فكرة قد تخطر للمبرمج هي ببساطة عد الأقواس. "لدي قوسا فتح وقوسا إغلاق، إذن الحل صحيح". لكن ماذا عن `")("`؟ أو `"([)]"`؟ هنا العدد صحيح، لكن الترتيب خاطئ تماماً. إذن، مجرد العد لا يكفي.
#
# #### **ثانياً: قاعدة "آخر قوس فُتح هو أول قوس يُغلق"**
#
# أدركت أن القوس الذي فتحته **آخراً** هو الذي يجب أن أغلقه **أولاً**. إذا فتحت `(` ثم `[`، لا يمكنني إغلاق `)` قبل أن أغلق `]`. هذا الترتيب ضروري جداً.
#
# #### **ثالثاً: اختيار هيكل البيانات (The Stack)**
#
# هذا السلوك (الآخر دخولاً هو الأول خروجاً) هو التعريف الحرفي لـ **المكدس (Stack)**.
#
# * كلما رأيت قوس فتح، أضعه في المكدس (Push) بانتظار إغلاقه.
# * كلما رأيت قوس إغلاق، أسحب آخر عنصر وضعته في المكدس (Pop) وأقارنهما. إذا لم يتطابقا، فالترتيب خاطئ.
#
# #### **رابعاً: معالجة الحالات الخاصة**
#
# ماذا لو بدأ النص بقوس إغلاق مثل `")"`؟ هنا المكدس سيكون فارغاً عندما أحاول السحب منه، لذا يجب أن أتأكد من وجود عناصر قبل السحب.
# وأيضاً، ماذا لو كان النص `"((("`؟ ستنتهي الحلقة والمكدس لا يزال يحتوي على أقواس لم تُغلق. لذا، الشرط النهائي هو أن يكون المكدس **فارغاً تماماً** في النهاية.
#
#
# ### **2. الحل**
#
# ```python
# def isValid(s):
#     # Dictionary to map closing brackets to their opening counterparts
#     mapping = {")": "(", "}": "{", "]": "["}
#     stack = []
#
#     for char in s:
#         # If the character is a closing bracket
#         if char in mapping:
#             # Pop the top element if stack is not empty, else use a dummy value
#             top_element = stack.pop() if stack else '#'
#
#             # If the popped element doesn't match the mapping, it's invalid
#             if mapping[char] != top_element:
#                 return False
#         else:
#             # It's an opening bracket, push it onto the stack
#             stack.append(char)
#
#     # If the stack is empty, all brackets were matched correctly
#     return not stack
#
# ```
# ---
#
# ### **3. التشبيه: كومة الصحون 🍽️**
#
# تخيل إنك عم تغسل صحون من أنواع مختلفة (صحن عميق، صحن مسطح، زبدية).
#
# * كل ما تجلي صحن، بتحطه فوق "الكومة" (Stack).
# * لما بدك تنشفهم وترجعهم لمكانهم، لازم تبدأ بآخر واحد حطيته فوق.
# * إذا كان الصحن اللي فوق "زبدية"، ومكان التخزين اللي عم تحاول تحط فيه هو للـ "صحن المسطح"، معناها صار فيه خربطة بالترتيب. لازم النوعين يطابقوا بعض تماماً.
#
# ---
#
# ### **4. تحليل التعقيد (Complexity Analysis)**
#
# * **التعقيد الزمني (Time Complexity):** هو  لأننا نمر على النص مرة واحدة فقط من البداية للنهاية.
# * **تعقيد المساحة (Space Complexity):** هو  لأننا في أسوأ حالة (مثل `"((((("`) قد نضطر لتخزين كل الأقواس داخل المكدس.
#
# ---
#
# **هل ترغب في أن ننتقل لمسألة "القوائم المترابطة" (Linked Lists) أم نتابع في مسائل الـ Strings؟**

# %%
def isValid(s):
    # Dictionary to map closing brackets to their opening counterparts
    mapping = {")": "(", "}": "{", "]": "["}
    stack = []

    for char in s:
        # If the character is a closing bracket
        if char in mapping:
            # Pop the top element if stack is not empty, else use a dummy value
            top_element = stack.pop() if stack else '#'
            
            # If the popped element doesn't match the mapping, it's invalid
            if mapping[char] != top_element:
                return False
        else:
            # It's an opening bracket, push it onto the stack
            stack.append(char)

    # If the stack is empty, all brackets were matched correctly
    return not stack
